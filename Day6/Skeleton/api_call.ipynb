# %% [markdown]
# browser can only send get request - otherwise need to use requests library

# %% [markdown]
# got lost around 11:30 am - post vs get?? her changes don't seem to work for me

# %%
import requests

response = requests.get("http://127.0.0.1:8000")
response.content
# Out:
# b'{"Hello":"World"}'

# %%
response.headers
# Out:
# {'date': 'Tue, 15 Sep 2026 18:29:38 GMT', 'server': 'uvicorn', 'content-length': '17', 'content-type': 'application/json'}

# %%
response_get = requests.get("http://127.0.0.1:8000/items")

# %%
response_post = requests.post("http://127.0.0.1:8000/items")
