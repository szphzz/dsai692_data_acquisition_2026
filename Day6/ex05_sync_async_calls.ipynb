# %%
import httpx

url = "http://127.0.0.1:8000/sync"
response = httpx.get(url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'first': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aa309e7-67252da11cab2d384e73054d'}, 'origin': '73.15.19.227', 'url': 'https://httpbin.org/delay/1.2'}, 'second': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aa309e8-21c1874672900faf060905d7'}, 'origin': '73.15.19.227', 'url': 'https://httpbin.org/delay/1.2'}}

# %%
import httpx

url = "http://127.0.0.1:8000/async"
async with httpx.AsyncClient() as client:
    response = await client.get(url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'first': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aa309ec-0d2d25cd337734aa796f0099'}, 'origin': '73.15.19.227', 'url': 'https://httpbin.org/delay/1.2'}, 'second': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aa309ee-26528c68558615284759d167'}, 'origin': '73.15.19.227', 'url': 'https://httpbin.org/delay/1.2'}}
