# %%
import httpx

url = "http://127.0.0.1:8000/sync"
response = httpx.get(url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'first': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aad8562-1968f130130fac9a1985eb6a'}, 'origin': '138.202.129.46', 'url': 'https://httpbin.org/delay/1.2'}, 'second': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aad8564-32069332308ed5c74c609fee'}, 'origin': '138.202.129.46', 'url': 'https://httpbin.org/delay/1.2'}}

# %%
import httpx

url = "http://127.0.0.1:8000/async"
async with httpx.AsyncClient() as client:  # faster by a bit yay!
    response = await client.get(url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'first': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aad8565-5c7692283073f3253525db64'}, 'origin': '138.202.129.46', 'url': 'https://httpbin.org/delay/1.2'}, 'second': {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-httpx/0.28.1', 'X-Amzn-Trace-Id': 'Root=1-6aad8567-0872d20d0321ab45336d4bd9'}, 'origin': '138.202.129.46', 'url': 'https://httpbin.org/delay/1.2'}}
