# %% [markdown]
# ### ex02
#
# - To build the image,
# ```sh
# docker build -t day8_ex01 .
# ```
# - To run day8_ex01,
# ```sh
# docker run -p 8080:8000 -v /Users/dwoodbridge/.ssh/gcp_dsai692.json:/tmp/gcp-key.json --env-file /Users/dwoodbridge/Class/2026_MSDS692/dsai692_data_acquisition_2026/Day8/.env day8_ex01
# ```
#
# format for mounting the volume: origin (local machine):destination (container)

# %%
import requests

url = 'https://data.sfgov.org/resource/wg3w-h783'
response = requests.post("http://127.0.0.1:8080/retrieve_and_store",
                        json={"url": url})

# %%
response.json()
# Out:
# {'message': 'Successfully stored the extracted data'}

# %% [markdown]
# ### ex03
#
# - To build the image,
# ```sh
# docker build -t day8_ex02 .
# ```
# - To run day8_ex01,
# ```sh
# docker run -v /Users/dwoodbridge/.ssh/gcp_dsai692.json:/tmp/gcp-key.json --env-file /Users/dwoodbridge/Class/2026_MSDS692/dsai692_data_acquisition_2026/Day8/.env -p 80:8501 day8_ex02
# ```
