# %%
import requests

url = "http://127.0.0.1:8000/add_items"  # the trailing slash doesn't matter
input = {"name": "Paper", "price": 12.4, "instock_qt": 10}
response = requests.post(url, json=input)  # use json= for Pydantic variables

# %%
response.content
# Out:
# b'{"total_worth":124.0}'

# %%
input = {"name": "Markers", "price": 6.0, "instock_qt": 2}
response = requests.post(url, json=input)

# %%
response.content
# Out:
# b'{"message":"Item added successfully","items":{"Paper":{"name":"Paper","price":12.4,"instock_qt":10},"Markers":{"name":"Markers","price":6.0,"instock_qt":2}}}'
