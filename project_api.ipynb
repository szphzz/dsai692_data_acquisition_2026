# %%
import requests

url = "https://data.sf.gov/resource/tkzw-k3nq.json"

response = requests.get(url)
response.raise_for_status()  # raises an error if the request failed

data = response.json()
print(data)
# Out:
# [{'treeid': '32105', 'legalstatus': 'DPW Maintained', 'species': 'Magnolia grandiflora :: Southern Magnolia', 'description': '181 Landers St | Tree 1', 'siteorder': '1', 'siteinfo': 'Sidewalk: Curb side : Cutout', 'planttype': 'Tree', 'planter': 'Private', 'waterresponsibility': 'FUF', 'planteddate': '1995-08-09', 'mapdbh': '6', 'xcoord': '6004531.31838', 'ycoord': '2106727.42232', 'latitude': '37.764928', 'longitude': '-122.427536', 'point': 'POINT(-122.427536 37.764928)', 'supervisordistrict': '8', 'analysis_neighborhood': 'Castro/Upper Market', 'dbhrange': '1', 'cnn': '08083000', 'roadwaydescription': 'ALERT ALY to 16TH ST (140 - 199)', 'onstreet': 'LANDERS ST', 'crossstreet': 'ALERT ALY', 'zip_code': '94114', 'data_as_of': '2026-07-01', 'data_loaded_at': '2026-09-18 09:41:35.664000-07:00'}, {'treeid': '38194', 'legalstatus': 'DPW Maintained', 'species': "Laurus x 'Saratoga' :: Hybrid Laurel", 'description': '722 Girard St | Tree 2', 'siteorder': '2', 'siteinfo': 'Sidewalk: Curb s
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   treeid                 1000 non-null   object
#  1   legalstatus            993 non-null    object
#  2   species                989 non-null    object
#  3   description            1000 non-null   object
#  4   siteorder              992 non-null    object
#  5   siteinfo               1000 non-null   object
#  6   planttype              1000 non-null   object
#  7   planter                998 non-null    object
#  8   waterresponsibility    316 non-null    object
#  9   planteddate            236 non-null    object
#  10  mapdbh                 927 non-null    object
#  11  xcoord                 1000 non-null   object
#  12  ycoord                 1000 non-null   object
#  13  latitude               1000 non-null   object
# ...
